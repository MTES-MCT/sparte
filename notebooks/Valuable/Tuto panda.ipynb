# %%
import numpy as np
import pandas as pd
from django.utils import timezone
from project.models import Project

# %%
# create a serie
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
# Create 12 months range with pandas date_range
start_year = f"{timezone.now().year}0101"
print(start_year)
dates = pd.date_range(start_year, periods=12)
dates
# Out:
# 20230101
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12'],
#               dtype='datetime64[ns]', freq='D')

# %%
np.random.randn(12, 4)
# Out:
# array([[ 0.45617107,  0.0494366 ,  0.66882714,  0.06348142],
#        [ 0.41644779,  1.92421611,  2.27004679,  1.35928577],
#        [-0.86144533, -0.64345315,  1.97016184, -0.39148387],
#        [-0.96122902,  1.01867434,  0.28380381,  0.11490189],
#        [-0.79903376, -0.15898906,  0.21268186, -0.69630612],
#        [-0.02772689,  1.55195656, -0.70922196, -2.21707534],
#        [ 1.31359025, -0.29240146,  1.43764078, -0.27051164],
#        [-0.04099131,  2.21628912,  0.40728345, -1.2428867 ],
#        [-0.82653359,  0.81464229, -0.78536703,  0.13841154],
#        [ 1.84927664, -0.35395997, -0.99791291,  1.08663304],
#        [-0.51959152, -1.41194527, -0.47834136, -0.7454151 ],
#        [-0.38187073,  0.57273535, -1.29850255,  0.70269689]])

# %%
# create a dataframe
# index = lignes or rows
df = pd.DataFrame(np.random.randn(12, 8), index=dates, columns=list("ABCDEFGH"))
df
# Out:
#                    A         B         C         D         E         F  \
# 2023-01-01 -0.527266 -0.694275 -0.178460 -0.527954  1.594993 -0.865541
# 2023-01-02 -0.222175  0.440893 -0.666219  1.711034  0.047138  0.611880
# 2023-01-03  0.166347 -1.566303 -3.334114 -0.386486  0.101729  0.039638
# 2023-01-04 -0.677812  1.143132  0.237951 -0.694721 -0.740539  1.796461
# 2023-01-05 -0.373964  0.248610  1.101990 -0.314119 -1.022939  1.572719
# 2023-01-06  0.910326 -0.637671 -0.598733 -1.742797 -0.638165  0.061818
# 2023-01-07 -0.422921 -0.321069 -0.455514 -0.361284  0.438306  0.317500
# 2023-01-08 -0.719987  1.308499  0.793471 -1.399481 -0.156834  0.377707
# 2023-01-09 -0.072706 -0.118497 -1.010448 -0.162207  0.522082  1.122719
# 2023-01-10 -1.151191  0.627199 -0.773136 -0.280737 -0.334952 -2.398680
# 2023-01-11  0.109129  0.564366  0.035396 -0.412176 -1.185931  3.019937
# 2023-01-12 -0.259272 -0.324706 -1.330759 -0.932114 -0.450189 -0.196375
#
#                    G         H
# 2023-01-01 -0.219944  0.115406
# 2023-01-02 -1.999100  0.062626
# 2023-01-03 -1.569193  1.336126
# 2023-01-04  0.084031 -0.379196
# 2023-01-05  1.203805 -2.421146
# 2023-01-06  0.323624  1.091594
# 2023-01-07  1.198392  0.501664
# 2023-01-08 -0.467302  0.174029
# 2023-01-09 -0.452163  1.233398
# 2023-01-10  2.378589 -0.060116
# 2023-01-11 -0.340804  0.818458
# 2023-01-12  0.904138  0.530046

# %%
# select october avec le label
# attention au format US qui inverse mois et jour :)
df.loc["20230110"]
# Out:
# A   -1.151191
# B    0.627199
# C   -0.773136
# D   -0.280737
# E   -0.334952
# F   -2.398680
# G    2.378589
# H   -0.060116
# Name: 2023-01-10 00:00:00, dtype: float64

# %%
# sélection de lignes en utilisant un index iloc
df.iloc[8:10]
# Out:
#                    A         B         C         D         E         F  \
# 2023-01-09 -0.072706 -0.118497 -1.010448 -0.162207  0.522082  1.122719
# 2023-01-10 -1.151191  0.627199 -0.773136 -0.280737 -0.334952 -2.398680
#
#                    G         H
# 2023-01-09 -0.452163  1.233398
# 2023-01-10  2.378589 -0.060116

# %%
# df["B":"E"] ==> error, can't slice by columns
# slicing rows (indexes)
df["20210102":"20210104"]
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E, F, G, H]
# Index: []

# %%
# subset avec les mois juillet à octobre et uniquement les colonnes A, B et E
df.loc["20210107":"20210110", ['B', 'A', 'E']]
# Out:
# Empty DataFrame
# Columns: [B, A, E]
# Index: []

# %%
# seulement juillet à otobre et toutes les colonnes de B à E
df.loc[["20210107","20210110"], "B":"E"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [11], line 2
#       1 # seulement juillet à otobre et toutes les colonnes de B à E
# ----> 2 df.loc[["20210107","20210110"], "B":"E"]
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:1256, in _LocIndexer._getitem_tuple(self, tup)
#    1253 if self._multi_take_opportunity(tup):
#    1254     return self._multi_take(tup)
# -> 1256 return self._getitem_tuple_same_dim(tup)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:924, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     921 if com.is_null_slice(key):
#     922     continue
# --> 924 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     925 # We should never have retval.ndim < self.ndim, as that should
#     926 #  be handled by the _getitem_lowerdim call above.
#     927 assert retval.ndim == self.ndim
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:1301, in _LocIndexer._getitem_axis(self, key, axis)
#    1298     if hasattr(key, "ndim") and key.ndim > 1:
#    1299         raise ValueError("Cannot index with multidimensional key")
# -> 1301     return self._getitem_iterable(key, axis=axis)
#    1303 # nested tuple slicing
#    1304 if is_nested_tuple(key, labels):
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:1239, in _LocIndexer._getitem_iterable(self, key, axis)
#    1236 self._validate_key(key, axis)
#    1238 # A collection of keys
# -> 1239 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1240 return self.obj._reindex_with_indexers(
#    1241     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1242 )
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py:1432, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1429 ax = self.obj._get_axis(axis)
#    1430 axis_name = self.obj._get_axis_name(axis)
# -> 1432 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1434 return keyarr, indexer
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py:6111, in Index._get_indexer_strict(self, key, axis_name)
#    6108 else:
#    6109     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6111 self._raise_if_missing(keyarr, indexer, axis_name)
#    6113 keyarr = self.take(indexer)
#    6114 if isinstance(key, Index):
#    6115     # GH 42790 - Preserve name from an Index
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py:6171, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6169     if use_interval_msg:
#    6170         key = list(key)
# -> 6171     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6173 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6174 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['20210107', '20210110'], dtype='object')] are in the [index]"

# %%
# accès à une colonne en utilisant un attribut
df.D
# Out:
# 2023-01-01   -0.527954
# 2023-01-02    1.711034
# 2023-01-03   -0.386486
# 2023-01-04   -0.694721
# 2023-01-05   -0.314119
# 2023-01-06   -1.742797
# 2023-01-07   -0.361284
# 2023-01-08   -1.399481
# 2023-01-09   -0.162207
# 2023-01-10   -0.280737
# 2023-01-11   -0.412176
# 2023-01-12   -0.932114
# Freq: D, Name: D, dtype: float64

# %%
# accès à un élément précis
df.D["20210108"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx:548, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1610064000000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx:516, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx:550, in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2021-01-08 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/datetimes.py:736, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     735 try:
# --> 736     return Index.get_loc(self, key, method, tolerance)
#     737 except KeyError as err:
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#
# KeyError: Timestamp('2021-01-08 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [13], line 2
#       1 # accès à un élément précis
# ----> 2 df.D["20210108"]
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/datetimes.py:738, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     736     return Index.get_loc(self, key, method, tolerance)
#     737 except KeyError as err:
# --> 738     raise KeyError(orig_key) from err
#
# KeyError: '20210108'

# %%
# identique à :
df["D"]["20210108"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx:548, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1610064000000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx:516, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx:550, in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2021-01-08 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/datetimes.py:736, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     735 try:
# --> 736     return Index.get_loc(self, key, method, tolerance)
#     737 except KeyError as err:
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#
# KeyError: Timestamp('2021-01-08 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [14], line 2
#       1 # identique à :
# ----> 2 df["D"]["20210108"]
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/datetimes.py:738, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     736     return Index.get_loc(self, key, method, tolerance)
#     737 except KeyError as err:
# --> 738     raise KeyError(orig_key) from err
#
# KeyError: '20210108'

# %%
df["D"]["20210108"] = "Hello"
df["D"]["20210108"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx:548, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1610064000000000000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx:516, in pandas._libs.index.DatetimeEngine.get_loc()
#
# File /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx:550, in pandas._libs.index.DatetimeEngine.get_loc()
#
# KeyError: Timestamp('2021-01-08 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/datetimes.py:736, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     735 try:
# --> 736     return Index.get_loc(self, key, method, tolerance)
#     737 except KeyError as err:
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#
# KeyError: Timestamp('2021-01-08 00:00:00')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [15], line 2
#       1 df["D"]["20210108"] = "Hello"
# ----> 2 df["D"]["20210108"]
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File /usr/local/lib/python3.9/site-packages/pandas/core/indexes/datetimes.py:738, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     736     return Index.get_loc(self, key, method, tolerance)
#     737 except KeyError as err:
# --> 738     raise KeyError(orig_key) from err
#
# KeyError: '20210108'

# %%
df
# Out:
#                    A         B         C         D         E         F  \
# 2023-01-01 -0.527266 -0.694275 -0.178460 -0.527954  1.594993 -0.865541
# 2023-01-02 -0.222175  0.440893 -0.666219  1.711034  0.047138  0.611880
# 2023-01-03  0.166347 -1.566303 -3.334114 -0.386486  0.101729  0.039638
#
#                    G         H  NEW
# 2023-01-01 -0.219944  0.115406    0
# 2023-01-02 -1.999100  0.062626    1
# 2023-01-03 -1.569193  1.336126    2
# 2023-01-04  0.084031 -0.379196    3
# 2023-01-05  1.203805 -2.421146    4
# 2023-01-06  0.323624  1.091594    5
# 2023-01-07  1.198392  0.501664    6
# 2023-01-08 -0.467302  0.174029    7
# 2023-01-09 -0.452163  1.233398    8
# 2023-01-10  2.378589 -0.060116    9
# 2023-01-11 -0.340804  0.818458   10
# 2023-01-12  0.904138  0.530046   11

# %%
# sélectionner uniquement les lignes pour lesquelles la valeur de la cellule en 1 est supérieur à 1
df[df["A"] > 1]
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E, F, G, H, NEW]
# Index: []

# %%
# on change la valeur "hello" pour une valeur numérique
# on utilise .at
df.at["20210108", "D"] = 1000
# on ne sélectionne que les valeurs qui sont plus grandes que 0
df[df > 0]
# Out:
#                    A         B         C            D         E         F  \
# 2023-01-01       NaN       NaN       NaN          NaN  1.594993       NaN
# 2023-01-02       NaN  0.440893       NaN     1.711034  0.047138  0.611880
# 2023-01-03  0.166347       NaN       NaN          NaN  0.101729  0.039638
# 2023-01-04       NaN  1.143132  0.237951          NaN       NaN  1.796461
# 2023-01-05       NaN  0.248610  1.101990          NaN       NaN  1.572719
# 2023-01-06  0.910326       NaN       NaN          NaN       NaN  0.061818
# 2023-01-07       NaN       NaN       NaN          NaN  0.438306  0.317500
# 2023-01-08       NaN  1.308499  0.793471          NaN       NaN  0.377707
# 2023-01-09       NaN       NaN       NaN          NaN  0.522082  1.122719
# 2023-01-10       NaN  0.627199       NaN          NaN       NaN       NaN
# 2023-01-11  0.109129  0.564366  0.035396          NaN       NaN  3.019937
# 2023-01-12       NaN       NaN       NaN          NaN       NaN       NaN
# 2021-01-08       NaN       NaN       NaN  1000.000000       NaN       NaN
#
#                    G         H   NEW
# 2023-01-01       NaN  0.115406   NaN
# 2023-01-02       NaN  0.062626   1.0
# 2023-01-03       NaN  1.336126   2.0
# 2023-01-04  0.084031       NaN   3.0
# 2023-01-05  1.203805       NaN   4.0
# 2023-01-06  0.323624  1.091594   5.0
# 2023-01-07  1.198392  0.501664   6.0
# 2023-01-08       NaN  0.174029   7.0
# 2023-01-09       NaN  1.233398   8.0
# 2023-01-10  2.378589       NaN   9.0
# 2023-01-11       NaN  0.818458  10.0
# 2023-01-12  0.904138  0.530046  11.0
# 2021-01-08       NaN       NaN   NaN

# %%
# transpose la matrice
df.T
# Out:
#      2023-01-01  2023-01-02  2023-01-03  2023-01-04  2023-01-05  2023-01-06  \
# A     -0.527266   -0.222175    0.166347   -0.677812   -0.373964    0.910326
# B     -0.694275    0.440893   -1.566303    1.143132    0.248610   -0.637671
# C     -0.178460   -0.666219   -3.334114    0.237951    1.101990   -0.598733
# D     -0.527954    1.711034   -0.386486   -0.694721   -0.314119   -1.742797
# E      1.594993    0.047138    0.101729   -0.740539   -1.022939   -0.638165
# F     -0.865541    0.611880    0.039638    1.796461    1.572719    0.061818
# G     -0.219944   -1.999100   -1.569193    0.084031    1.203805    0.323624
# H      0.115406    0.062626    1.336126   -0.379196   -2.421146    1.091594
# NEW    0.000000    1.000000    2.000000    3.000000    4.000000    5.000000
#
#      2023-01-07  2023-01-08  2023-01-09  2023-01-10  2023-01-11  2023-01-12  \
# A     -0.422921   -0.719987   -0.072706   -1.151191    0.109129   -0.259272
# B     -0.321069    1.308499   -0.118497    0.627199    0.564366   -0.324706
# C     -0.455514    0.793471   -1.010448   -0.773136    0.035396   -1.330759
# D     -0.361284   -1.399481   -0.162207   -0.280737   -0.412176   -0.932114
# E      0.438306   -0.156834    0.522082   -0.334952   -1.185931   -0.450189
# F      0.317500    0.377707    1.122719   -2.398680    3.019937   -0.196375
# G      1.198392   -0.467302   -0.452163    2.378589   -0.340804    0.904138
# H      0.501664    0.174029    1.233398   -0.060116    0.818458    0.530046
# NEW    6.000000    7.000000    8.000000    9.000000   10.000000   11.000000
#
#      2021-01-08
# A           NaN
# B           NaN
# C           NaN
# D        1000.0
# E           NaN
# F           NaN
# G           NaN
# H           NaN
# NEW         NaN

# %%
# copy only a subset of the dataframe (6 first lines)
df2 = df.iloc[0:6].copy()
# replace column value
df2["E"] = ["one", "one", "two", "three", "four", "three"]
# select only rows if value in column E is two or four
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E         F         G  \
# 2023-01-03  0.166347 -1.566303 -3.334114 -0.386486   two  0.039638 -1.569193
# 2023-01-05 -0.373964  0.248610  1.101990 -0.314119  four  1.572719  1.203805
#
#                    H  NEW
# 2023-01-03  1.336126  2.0
# 2023-01-05 -2.421146  4.0

# %%
# sélection basée sur une valeur booléenne
df2["E"].isin(["two", "four"])
# Out:
# 2023-01-01    False
# 2023-01-02    False
# 2023-01-03     True
# 2023-01-04    False
# 2023-01-05     True
# 2023-01-06    False
# Name: E, dtype: bool

# %%
# sélectionne les lignes impaires
df2[[i%2 == 0 for i in range(6)]]
# Out:
#                    A         B         C         D     E         F         G  \
# 2023-01-01 -0.527266 -0.694275 -0.178460 -0.527954   one -0.865541 -0.219944
# 2023-01-03  0.166347 -1.566303 -3.334114 -0.386486   two  0.039638 -1.569193
# 2023-01-05 -0.373964  0.248610  1.101990 -0.314119  four  1.572719  1.203805
#
#                    H  NEW
# 2023-01-01  0.115406  0.0
# 2023-01-03  1.336126  2.0
# 2023-01-05 -2.421146  4.0

# %%
# créer une série qui ne couvre que partiellement les index de df
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20210102", periods=6))
s1
# Out:
# 2021-01-02    1
# 2021-01-03    2
# 2021-01-04    3
# 2021-01-05    4
# 2021-01-06    5
# 2021-01-07    6
# Freq: D, dtype: int64

# %%
# ajouter cette colonne à df, remarquez que c'est placé correctement dans le tableau
df["I"] = s1
df
# Out:
#                    A         B         C            D         E         F  \
# 2023-01-01 -0.527266 -0.694275 -0.178460    -0.527954  1.594993 -0.865541
# 2023-01-02 -0.222175  0.440893 -0.666219     1.711034  0.047138  0.611880
# 2023-01-03  0.166347 -1.566303 -3.334114    -0.386486  0.101729  0.039638
# 2023-01-04 -0.677812  1.143132  0.237951    -0.694721 -0.740539  1.796461
# 2023-01-05 -0.373964  0.248610  1.101990    -0.314119 -1.022939  1.572719
# 2023-01-06  0.910326 -0.637671 -0.598733    -1.742797 -0.638165  0.061818
# 2023-01-07 -0.422921 -0.321069 -0.455514    -0.361284  0.438306  0.317500
# 2023-01-08 -0.719987  1.308499  0.793471    -1.399481 -0.156834  0.377707
# 2023-01-09 -0.072706 -0.118497 -1.010448    -0.162207  0.522082  1.122719
# 2023-01-10 -1.151191  0.627199 -0.773136    -0.280737 -0.334952 -2.398680
# 2023-01-11  0.109129  0.564366  0.035396    -0.412176 -1.185931  3.019937
# 2023-01-12 -0.259272 -0.324706 -1.330759    -0.932114 -0.450189 -0.196375
# 2021-01-08       NaN       NaN       NaN  1000.000000       NaN       NaN
#
#                    G         H   NEW   I
# 2023-01-01 -0.219944  0.115406   0.0 NaN
# 2023-01-02 -1.999100  0.062626   1.0 NaN
# 2023-01-03 -1.569193  1.336126   2.0 NaN
# 2023-01-04  0.084031 -0.379196   3.0 NaN
# 2023-01-05  1.203805 -2.421146   4.0 NaN
# 2023-01-06  0.323624  1.091594   5.0 NaN
# 2023-01-07  1.198392  0.501664   6.0 NaN
# 2023-01-08 -0.467302  0.174029   7.0 NaN
# 2023-01-09 -0.452163  1.233398   8.0 NaN
# 2023-01-10  2.378589 -0.060116   9.0 NaN
# 2023-01-11 -0.340804  0.818458  10.0 NaN
# 2023-01-12  0.904138  0.530046  11.0 NaN
# 2021-01-08       NaN       NaN   NaN NaN

# %%
# in place modification of the data
# with "where" sélection
df2 = df.iloc[0:4, 0:4].copy().fillna(0)
df2[df2 > 0] = -df2
df2
# Out:
#                    A         B         C         D
# 2023-01-01 -0.527266 -0.694275 -0.178460 -0.527954
# 2023-01-02 -0.222175 -0.440893 -0.666219 -1.711034
# 2023-01-03 -0.166347 -1.566303 -3.334114 -0.386486
# 2023-01-04 -0.677812 -1.143132 -0.237951 -0.694721

# %%
project = Project.objects.all().first()
data = [[k,v] for k, v in project.get_pop_change_per_year("pop").items()]
df = pd.DataFrame(data, columns=["year", "pop"]).fillna("")
df
# Out:
#    year    pop
# 0  2011  443.0
# 1  2012  200.0
# 2  2013   65.0
# 3  2014  -32.0
# 4  2015  152.0
# 5  2016 -314.0
# 6  2017  298.0
# 7  2018  220.0
# 8  2019  -37.0
# 9  2020

# %%
df.pivot(columns=["year"], inex=["pop"], values="pop")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 df.pivot(columns=["year"], inex=["pop"], values="pop")
#
# File /usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: pivot() got an unexpected keyword argument 'inex'

# %%
project.get_pop_change_per_year("pop")
# Out:
# {'2011': 443,
#  '2012': 200,
#  '2013': 65,
#  '2014': -32,
#  '2015': 152,
#  '2016': -314,
#  '2017': 298,
#  '2018': 220,
#  '2019': -37,
#  '2020': None}
